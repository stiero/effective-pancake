# %% [markdown]
# ### Natural Language Understanding Challenge

# %% [markdown]
# To begin with - Due to the short timeframe, I wasn't able to refactor / beautify my code to the extent I would've liked.
#
# As I wrote more lines of code and iterated between several ideas, the complexity increased - and so my code might look a little off. Also, pardon the variable names if they are confusing.
#
# My production-grade code is a lot cleaner than this. :)

# %% [markdown]
# ###### Data preparation and cleaning - the cornerstone of any NLP task

# %%
# Importing all necessary stuff

import json
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
class DataGetter():
    
    def __init__(self, filename):
        
        self.df = pd.read_json(filename)
        
        self.df['text'] = None
        self.df['intent'] = None
        self.df['entities'] = None
        self.df['training'] = None
        
        for index, row in self.df.iterrows():
            for key, value in self.df.iloc[index].sentences.items():
                self.df.iloc[index][key] = value
            
    
    
    
    
    def get_sentences(self):
        self.sentences = self.df.text.tolist()
        return self.sentences





    def clean_and_tokenise(self):   
        
        self.get_sentences()
    
        for i, sent in enumerate(self.sentences):
            self.sentences[i] = re.sub('[.!]+', "", sent)            
        
        self.sentences_tokenised = list(map(lambda x: re.split(" |(-)|'|(:)|(,)|(\?)", x), self.sentences))
        
        for i, sent in enumerate(self.sentences_tokenised):
            self.sentences_tokenised[i] = list(filter(None, sent))
            
        return self.sentences_tokenised
            


    
    def get_unique_entities(self):
        self.unique_ents = list(set([dict_['entity'] for sentence in self.df.entities for dict_ in sentence]))
        return self.unique_ents

        
    def get_unique_intents(self):
        self.unique_intents = list(set(self.df.intent))
        return self.unique_intents
        
    
    def get_entities(self):
        
        self.clean_and_tokenise()
        
        self.entitites_start_stop = df.entities.apply(lambda x: [(w['start'], w['stop']) for w in x])
    
        self.entity_sequence = list(map(lambda x: ['O' for word in x], self.sentences_tokenised))
        

        for i, sent in enumerate(self.sentences_tokenised):
            for ent in self.df.iloc[i].entities:
                start = ent['start']
                stop = ent['stop']
                
                entity = ent['entity']
                                
                
                self.entity_sequence[i][start:stop+1] = [entity for i in 
                                                         range(len(self.entity_sequence[i][start:stop+1]))]


        return self.entity_sequence

# %%
# Instantiating class
data = DataGetter('ChatbotCorpus.json')

# Getting the DataFrame object
df = data.df

# Getting unique entities in the corpus
unique_entities = data.get_unique_entities()

# Getting cleaned and tokenised sentences
sentences = data.clean_and_tokenise()

# Getting entities
entities = data.get_entities()

entities_start_stop = df.entities.apply(lambda x: [(w['start'], w['stop']) for w in x])

unique_intents = data.get_unique_intents()

# %%
entities = list(map(lambda x: ['O' for word in x], sentences))

# %%
entities
# Out:
# [['O', 'O', 'O', 'O', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'Vehicle',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'Vehicle',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['StationStart', 'O', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationDest',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationDest',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'StationDest', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest', 'O', 'StationStart'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart', 'StationStart'],
#  ['O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'Vehicle', 'O', 'O', 'StationStart', 'StationStart'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart', 'StationStart'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart', 'O', 'O'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart', 'StationStart'],
#  ['O', 'StationStart', 'O', 'StationDest'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'Vehicle',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'Vehicle',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest', 'O'],
#  ['StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest'],
#  ['StationStart', 'O', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'Vehicle', 'O', 'StationStart', 'O', 'StationDest'],
#  ['StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart', 'StationStart'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart', 'StationStart'],
#  ['O', 'O', 'StationStart', 'O', 'O', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'Vehicle',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'O'],
#  ['O', 'Criterion', 'Vehicle', 'O', 'StationStart', 'StationStart'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'StationStart'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Line',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart', 'StationStart'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'StationStart', 'O', 'StationDest'],
#  ['O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'StationStart', 'O', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O',
#   'TimeStartTime',
#   'TimeStartTime',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O',
#   'TimeStartTime',
#   'TimeStartTime',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'StationDest',
#   'StationDest',
#   'StationDest',
#   'O',
#   'TimeStartTime',
#   'TimeStartTime'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationDest',
#   'O',
#   'TimeEndTime',
#   'TimeEndTime',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest', 'O', 'TimeEndTime'],
#  ['O', 'O', 'O', 'O', 'Vehicle', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'O', 'Vehicle', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'Vehicle', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O',
#   'O',
#   'TimeStartTime',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O',
#   'TimeStartTime',
#   'TimeStartTime',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'O',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'StationDest',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'O',
#   'O'],
#  ['O', 'O', 'O', 'O', 'Line', 'O', 'O', 'StationStart', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart'],
#  ['O', 'O', 'O', 'Criterion', 'Line', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart', 'O', 'O', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'O', 'Vehicle', 'O', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'Vehicle',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'Vehicle',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Vehicle', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'Vehicle', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Vehicle', 'O', 'StationStart', 'O', 'O'],
#  ['Criterion', 'Vehicle', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Vehicle', 'O', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'Vehicle', 'O', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'O',
#   'StationDest',
#   'StationDest',
#   'O'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationDest', 'O', 'StationStart', 'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest'],
#  ['O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart', 'O'],
#  ['O',
#   'O',
#   'O',
#   'Criterion',
#   'Vehicle',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O'],
#  ['O', 'O', 'StationStart', 'O', 'StationDest', 'O'],
#  ['O',
#   'O',
#   'O',
#   'O',
#   'O',
#   'StationStart',
#   'StationStart',
#   'O',
#   'StationDest',
#   'O'],
#  ['O', 'O', 'O', 'Criterion', 'Vehicle', 'O', 'StationStart', 'StationStart'],
#  ['O', 'O', 'O', 'O', 'O', 'StationStart', 'O', 'StationDest'],
#  ['O', 'StationStart', 'O', 'StationDest']]
